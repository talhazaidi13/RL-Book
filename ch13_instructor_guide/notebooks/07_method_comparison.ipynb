# %% [markdown]
# # Exercise 18: Method Comparison
#
# This notebook provides an instructor-facing comparison matrix and a reproducible experimental checklist.

# %%
import pandas as pd

comparison = pd.DataFrame([
    {
        "method": "Behavior cloning",
        "data": "Expert demonstrations",
        "objective": "Match demonstrated actions",
        "strength": "Stable and simple",
        "risk": "Covariate shift",
        "best_use": "Strong demonstrations and narrow deployment",
    },
    {
        "method": "Online RL",
        "data": "Interactive rollouts and reward",
        "objective": "Maximize expected return",
        "strength": "Can discover recovery and improve task success",
        "risk": "Unsafe and sample-intensive exploration",
        "best_use": "Safe simulator or controlled fine-tuning",
    },
    {
        "method": "Diffusion policy",
        "data": "Demonstrated action chunks",
        "objective": "Learn conditional denoising distribution",
        "strength": "Multimodal, temporally coherent actions",
        "risk": "Iterative inference; no direct reward optimization",
        "best_use": "Multimodal visuomotor manipulation",
    },
])
comparison

# %%
controlled_factors = [
    "Observation definition",
    "Action representation and scaling",
    "Training-data or interaction budget",
    "Network capacity",
    "Random seeds",
    "Success metric",
    "Safety-filter configuration",
    "Inference hardware and latency",
    "Reset distribution",
    "Failure taxonomy",
]
pd.DataFrame({"control_in_comparison": controlled_factors})

# %% [markdown]
# ## Recommended conclusion
#
# No single method dominates every setting. Demonstration-based pretraining or diffusion modeling can solve exploration and multimodality, while carefully constrained RL can improve recovery and task success. The correct comparison controls the robotic interface and data budget rather than comparing unrelated benchmark numbers.
